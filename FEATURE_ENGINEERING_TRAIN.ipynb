# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
df_train=pd.read_csv(r'C:\Users\kesha\data_set\advance_houseprice_prediction_train.csv')

# %%
df_cpy=df_train.copy()

# %%
##handling missing value in categorical feature
feature_cat_na=[feature for feature in df_cpy.columns if df_cpy[feature].isnull().sum()>0 and df_cpy[feature].dtypes=='O']
len(feature_cat_na)
# Out:
# 16

# %%
data=df_cpy.copy()
for feature in feature_cat_na:
    #data=df_cpy.copy()
    data[feature]=data[feature].fillna('Missing')

# %%
df_cpy[feature_cat_na]=data[feature_cat_na]
df_cpy[feature_cat_na].head()
# Out:
#      Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0  Missing    BrkFace       Gd       TA           No          GLQ
# 1  Missing       None       Gd       TA           Gd          ALQ
# 2  Missing    BrkFace       Gd       TA           Mn          GLQ
# 3  Missing       None       TA       Gd           No          ALQ
# 4  Missing    BrkFace       Gd       TA           Av          GLQ
#
#   BsmtFinType2 Electrical FireplaceQu GarageType GarageFinish GarageQual  \
# 0          Unf      SBrkr     Missing     Attchd          RFn         TA
# 1          Unf      SBrkr          TA     Attchd          RFn         TA
# 2          Unf      SBrkr          TA     Attchd          RFn         TA
# 3          Unf      SBrkr          Gd     Detchd          Unf         TA
# 4          Unf      SBrkr          TA     Attchd          RFn         TA
#
#   GarageCond   PoolQC    Fence MiscFeature
# 0         TA  Missing  Missing     Missing
# 1         TA  Missing  Missing     Missing
# 2         TA  Missing  Missing     Missing
# 3         TA  Missing  Missing     Missing
# 4         TA  Missing  Missing     Missing

# %% [raw]
# HANDLING MISSING VALUES IN NUMERIC FEATURES

# %%
##handling missing value in numerical feature
feature_num_na=[feature for feature in df_cpy.columns if df_cpy[feature].isnull().sum()>0 and df_cpy[feature].dtypes!='O']

# %%
feature_num_na
len(df_cpy['LotFrontage'])
# Out:
# 1460

# %%
## We will print the numerical nan variables and percentage of missing values

for feature in feature_num_na:
    print("{}: {}% missing value".format(feature,np.around(df_cpy[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1774% missing value
# MasVnrArea: 0.0055% missing value
# GarageYrBlt: 0.0555% missing value

# %%
df_cpy[feature_num_na]=df_cpy[feature_num_na].fillna(df_cpy[feature_num_na].median())
#df_cpy['LotFrontage'].median()
df_cpy[feature_num_na].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %% [markdown]
# HANDLING TEMPORAL VARIABLES

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    
       
    df_cpy[feature]=df_cpy['YrSold']-df_cpy[feature]

# %%
df_cpy.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5          5
# 1       Norm     1Fam     1Story            6            8         31
# 2       Norm     1Fam     2Story            7            5          7
# 3       Norm     1Fam     2Story            7            5         91
# 4       Norm     1Fam     2Story            8            5          8
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             5     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1            31     Gable  CompShg     MetalSd     MetalSd       None
# 2             6     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3            36     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             8     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0     Missing
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd          5.0          RFn           2         548         TA
# 1     Attchd         31.0          RFn           2         460         TA
# 2     Attchd          7.0          RFn           2         608         TA
# 3     Detchd          8.0          Unf           3         642         TA
# 4     Attchd          8.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# 0            0         0  Missing  Missing     Missing        0       2
# 1            0         0  Missing  Missing     Missing        0       5
# 2            0         0  Missing  Missing     Missing        0       9
# 3            0         0  Missing  Missing     Missing        0       2
# 4            0         0  Missing  Missing     Missing        0      12
#
#    YrSold SaleType SaleCondition  SalePrice
# 0    2008       WD        Normal     208500
# 1    2007       WD        Normal     181500
# 2    2008       WD        Normal     223500
# 3    2006       WD       Abnorml     140000
# 4    2008       WD        Normal     250000

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    df_cpy[feature]=np.log(df_cpy[feature])

# %% [markdown]
# HANDLING RARE CATEGORICAL FEATURE
# #we will remove categorical variables that are present less than 1% of observation

# %%
categorical_features=[feature for feature in df_cpy.columns if df_cpy[feature].dtype=='O']
categorical_features
for feature in categorical_features:
    print("{}: {}".format(feature,len(df_cpy[feature].unique())))
# Out:
# MSZoning: 5
# Street: 2
# Alley: 3
# LotShape: 4
# LandContour: 4
# Utilities: 2
# LotConfig: 5
# LandSlope: 3
# Neighborhood: 25
# Condition1: 9
# Condition2: 8
# BldgType: 5
# HouseStyle: 8
# RoofStyle: 6
# RoofMatl: 8
# Exterior1st: 15
# Exterior2nd: 16
# MasVnrType: 5
# ExterQual: 4
# ExterCond: 5
# Foundation: 6
# BsmtQual: 5
# BsmtCond: 5
# BsmtExposure: 5
# BsmtFinType1: 7
# BsmtFinType2: 7
# Heating: 6
# HeatingQC: 5
# CentralAir: 2
# Electrical: 6
# KitchenQual: 4
# Functional: 7
# FireplaceQu: 6
# GarageType: 7
# GarageFinish: 4
# GarageQual: 6
# GarageCond: 6
# PavedDrive: 3
# PoolQC: 4
# Fence: 5
# MiscFeature: 5
# SaleType: 9
# SaleCondition: 6

# %%
data=df_cpy.copy()
for feature in categorical_features:
    temp=data[feature].value_counts()/len(data)
    temp_df=temp[temp>0.01].index
    data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_var')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7d958d116e8f> in <module>
#       1 data=df_cpy.copy()
# ----> 2 for feature in categorical_features:
#       3     temp=data[feature].value_counts()/len(data)
#       4     temp_df=temp[temp>0.01].index
#       5     data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_var')
#
# NameError: name 'categorical_features' is not defined

# %%
data[data['SaleType']=='Rare_var']
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street    Alley  \
# 88      89          50  Rare_var     4.653960  9.044286      Pave  Missing
# 140    141          20        RL     4.248495  9.259131      Pave  Missing
# 144    145          90        RM     4.248495  9.116030      Pave  Missing
# 221    222          60        RL     4.234107  8.995661      Pave  Missing
# 253    254          80        RL     4.442651  9.143132      Pave  Missing
# 282    283         120        RL     3.526361  8.529714      Pave  Missing
# 326    327         120        RL     3.465736  9.291552      Pave  Missing
# 352    353          50        RL     4.094345  9.114270      Pave  Missing
# 362    363          85        RL     4.158883  8.895767      Pave  Missing
# 431    432          50        RM     4.094345  8.628019      Pave  Missing
# 435    436          60        RL     3.761200  9.274910      Pave  Missing
# 439    440          50        RL     4.204693  9.421735      Pave     Grvl
# 488    489         190        RL     4.094345  9.287301      Pave  Missing
# 591    592          60        RL     4.574711  9.508814      Pave  Missing
# 636    637          30        RM     3.931826  8.719317      Pave  Missing
# 762    763          60        FV     4.276666  9.064158      Pave  Missing
# 811    812         120        RM     4.234107  8.397959      Pave  Missing
# 885    886         120        FV     3.912023  8.540714      Pave  Missing
# 942    943          90        RL     3.737670  8.950403      Pave  Missing
# 969    970         190        RL     4.317488  9.247829      Pave  Missing
# 985    986         190        RL     4.219508  9.294682      Pave  Missing
# 1061  1062          30  Rare_var     4.787492  9.798127  Rare_var  Missing
# 1075  1076          70        RL     4.317488  9.482274      Pave  Missing
# 1131  1132          20        RL     4.143135  9.279120      Pave  Missing
# 1158  1159          20        RL     4.521789  9.386979      Pave  Missing
# 1197  1198          75        RM     4.174387  9.088173      Pave  Missing
# 1200  1201          20        RL     4.262680  9.143452      Pave  Missing
# 1387  1388          50        RM     4.094345  9.050172      Pave     Grvl
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 88        IR1         Lvl    AllPub    Corner       Gtl       IDOTRR
# 140       Reg         Lvl    AllPub       FR2       Gtl        NAmes
# 144       Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 221       IR1         Lvl    AllPub    Inside       Gtl      Gilbert
# 253       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 282       Reg         Lvl    AllPub    Inside       Gtl      NridgHt
# 326       IR1         Lvl    AllPub   CulDSac       Gtl     Rare_var
# 352       Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 362       Reg         Lvl    AllPub    Corner       Gtl      Edwards
# 431       IR1         Bnk    AllPub    Inside       Gtl      OldTown
# 435       IR2         Lvl    AllPub   CulDSac       Gtl      CollgCr
# 439       Reg         Lvl    AllPub    Corner       Gtl      Edwards
# 488       Reg         Lvl    AllPub    Corner       Gtl      OldTown
# 591       IR1         Lvl    AllPub    Corner       Gtl      NridgHt
# 636       Reg         Lvl    AllPub    Inside       Gtl      BrkSide
# 762       Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 811       Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 885       IR1         Lvl    AllPub   CulDSac       Gtl      Somerst
# 942       IR1         Lvl    AllPub    Inside       Gtl      Edwards
# 969       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 985       Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 1061      Reg         Low    AllPub    Inside       Gtl       IDOTRR
# 1075      Reg         Lvl    AllPub    Inside       Gtl      Crawfor
# 1131      Reg         Lvl    AllPub    Inside       Gtl      Mitchel
# 1158      Reg         Lvl    AllPub       FR2       Gtl      Somerst
# 1197      IR1         Bnk    AllPub    Corner       Gtl      OldTown
# 1200      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1387      Reg         Lvl    AllPub    Inside       Gtl      OldTown
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 88        Feedr   Rare_var     1Fam     1.5Fin            3            2
# 140        Norm       Norm     1Fam     1Story            4            5
# 144    Rare_var       Norm   Duplex     1Story            5            5
# 221        Norm       Norm     1Fam     2Story            6            5
# 253        Norm       Norm     1Fam       SLvl            6            7
# 282        Norm       Norm    Twnhs     1Story            7            5
# 326        Norm       Norm   TwnhsE     1Story            8            5
# 352      Artery       Norm     1Fam     1.5Fin            5            6
# 362        Norm       Norm     1Fam     SFoyer            7            5
# 431       Feedr       Norm     1Fam     1.5Fin            6            7
# 435        PosN       Norm     1Fam     2Story            7            6
# 439        Norm       Norm     1Fam     1.5Fin            6            8
# 488        Norm       Norm   2fmCon     1.5Fin            5            4
# 591        Norm       Norm     1Fam     2Story           10            5
# 636        Norm       Norm     1Fam     1Story            2            3
# 762        Norm       Norm     1Fam     2Story            7            5
# 811        Norm       Norm   TwnhsE     1Story            6            5
# 885        Norm       Norm   TwnhsE     1Story            9            5
# 942        Norm       Norm   Duplex     1Story            4            3
# 969        Norm       Norm   2fmCon       SLvl            6            5
# 985        Norm       Norm   2fmCon     1Story            5            5
# 1061       Norm       Norm     1Fam     1Story            3            4
# 1075       Norm       Norm     1Fam     2Story            7            6
# 1131       Norm       Norm     1Fam     1Story            5            5
# 1158      Feedr       Norm     1Fam     1Story            8            5
# 1197       Norm       Norm     1Fam   Rare_var            7            6
# 1200       Norm       Norm     1Fam     1Story            4            5
# 1387     Artery       Norm     1Fam     1.5Fin            6            7
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 88           94            27       Hip  CompShg     Plywood     Plywood
# 140          39            39     Gable  CompShg     HdBoard     HdBoard
# 144          43            43     Gable  CompShg     HdBoard     HdBoard
# 221           7             7     Gable  CompShg     VinylSd     VinylSd
# 253          43            16       Hip  CompShg     HdBoard     HdBoard
# 282           2             1     Gable  CompShg     VinylSd     VinylSd
# 326          15            15     Gable  CompShg     BrkFace     BrkFace
# 352          67            58     Gable  CompShg     VinylSd     VinylSd
# 362           6             6     Gable  CompShg     HdBoard     HdBoard
# 431          88            10     Gable  CompShg     MetalSd     MetalSd
# 435          13            13     Gable  CompShg     VinylSd     VinylSd
# 439          89             9     Gable  CompShg     Wd Sdng     Wd Sdng
# 488         106            36     Gable  CompShg     Wd Sdng     Wd Sdng
# 591           1             1     Gable  CompShg     CemntBd     CmentBd
# 636          73            59     Gable  CompShg     AsbShng     AsbShng
# 762           1             1     Gable  CompShg     VinylSd     VinylSd
# 811           4             4     Gable  CompShg     VinylSd     VinylSd
# 885           9             8     Gable  CompShg     MetalSd     MetalSd
# 942          30            30     Gable  CompShg     MetalSd     MetalSd
# 969          48            48       Hip  CompShg     HdBoard     HdBoard
# 985          58            58     Gable  CompShg     MetalSd     MetalSd
# 1061         73            58     Gable  CompShg     MetalSd     MetalSd
# 1075         67            23     Gable  CompShg     Wd Sdng     Wd Sdng
# 1131         16            15     Gable  CompShg     HdBoard     HdBoard
# 1158          1             0     Gable  CompShg     VinylSd     VinylSd
# 1197         90            56     Gable  CompShg     MetalSd     MetalSd
# 1200         36            36     Gable  CompShg     MetalSd     MetalSd
# 1387         91            57     Gable  CompShg      Stucco      Stucco
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 88         None         0.0  Rare_var        Fa     CBlock       TA       Fa
# 140        None         0.0        TA        TA     CBlock       TA       TA
# 144     BrkFace       336.0        TA        TA     CBlock       TA       TA
# 221        None         0.0        Gd        TA      PConc       Gd       TA
# 253     BrkFace       108.0        TA        TA     CBlock       Gd       TA
# 282       Stone       166.0        Gd        TA      PConc       Gd       TA
# 326        None         0.0        Gd        TA      PConc       Gd       TA
# 352        None         0.0        TA        TA     CBlock       TA       Fa
# 362     BrkFace       500.0        Gd        TA       Slab  Missing  Missing
# 431        None         0.0        TA        TA     BrkTil       TA       TA
# 435        None         0.0        Gd        TA      PConc       Gd       TA
# 439        None         0.0        TA        TA     BrkTil       TA       Fa
# 488        None         0.0        TA        Fa     CBlock       TA       Fa
# 591       Stone       420.0        Ex        TA      PConc       Ex       TA
# 636        None         0.0  Rare_var        Fa     BrkTil       TA       Fa
# 762        None         0.0        TA        TA      PConc       Gd       TA
# 811     BrkFace       169.0        Gd        TA      PConc       Gd       TA
# 885     BrkFace        60.0        Gd        TA      PConc       Ex       TA
# 942        None         0.0        TA        TA      PConc       Gd       TA
# 969     BrkFace       105.0        TA        Fa     CBlock       TA       TA
# 985        None         0.0        TA        TA     CBlock       TA       TA
# 1061       None         0.0  Rare_var        TA     CBlock       TA       TA
# 1075       None         0.0        TA        TA     CBlock       TA       TA
# 1131       None         0.0        TA        TA      PConc       Gd       TA
# 1158      Stone       186.0        Gd        TA      PConc       Gd       TA
# 1197       None         0.0        TA        TA     BrkTil       TA       TA
# 1200       None         0.0        TA        TA     CBlock       TA       TA
# 1387       None         0.0        TA        Gd     BrkTil       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 88             No          Unf           0          Unf           0
# 140            No          ALQ         432          Unf           0
# 144            No          Rec        1332          Unf           0
# 221            No          Unf           0          Unf           0
# 253            Gd          LwQ         270          ALQ         580
# 282            No          GLQ         904          Unf           0
# 326            Gd          GLQ        1619          Unf           0
# 352            Mn          LwQ         236          Rec         380
# 362       Missing      Missing           0      Missing           0
# 431            No          Unf           0          Unf           0
# 435            Av          GLQ         385          ALQ         344
# 439            Mn          Unf           0          Unf           0
# 488            No          BLQ         664          Unf           0
# 591            Gd          GLQ        1338          Unf           0
# 636            No          Unf           0          Unf           0
# 762            Mn          GLQ          24          Unf           0
# 811            Gd          GLQ         662          Unf           0
# 885            Av          GLQ        1238          Unf           0
# 942            Gd          GLQ        1440          Unf           0
# 969            Gd          ALQ         513          Unf           0
# 985            No          ALQ        1040          Unf           0
# 1061           No          Unf           0          Unf           0
# 1075           No          BLQ         410          Unf           0
# 1131           Mn          BLQ         212          Unf           0
# 1158           No          Unf           0          Unf           0
# 1197           No          Unf           0          Unf           0
# 1200           No          Unf           0          Unf           0
# 1387           No          Rec         168          LwQ         546
#
#       BsmtUnfSF  TotalBsmtSF   Heating HeatingQC CentralAir Electrical  \
# 88         1013         1013      GasA        TA          N      SBrkr
# 140         432          864      GasA        TA          Y      SBrkr
# 144         396         1728      GasA        TA          Y      SBrkr
# 221        1010         1010      GasA        Ex          Y      SBrkr
# 253         452         1302      GasA        Ex          Y      SBrkr
# 282         410         1314      GasA        Ex          Y      SBrkr
# 326         100         1719      GasA        Ex          Y      SBrkr
# 352           0          616      GasA        TA          N      SBrkr
# 362           0            0      GasA        Ex          Y      SBrkr
# 431         901          901      GasA        Gd          Y      SBrkr
# 435          70          799      GasA        Ex          Y      SBrkr
# 439         684          684      GasA        Gd          Y      SBrkr
# 488         290          954      GasA        TA          N      FuseA
# 591         384         1722      GasA        Ex          Y      SBrkr
# 636         264          264  Rare_var        Fa          N      FuseA
# 762         732          756      GasA        Ex          Y      SBrkr
# 811         186          848      GasA        Ex          Y      SBrkr
# 885         460         1698      GasA        Ex          Y      SBrkr
# 942           0         1440      GasA        TA          Y      SBrkr
# 969          75          588      GasA        TA          Y      SBrkr
# 985         124         1164      GasW        TA          N      SBrkr
# 1061        894          894      GasA        TA          Y      SBrkr
# 1075        390          800      GasA        TA          Y      SBrkr
# 1131        762          974      GasA        TA          Y      SBrkr
# 1158       1580         1580      GasA        Ex          Y      SBrkr
# 1197        815          815      GasA        Ex          Y      SBrkr
# 1200        864          864      GasA        Gd          Y      SBrkr
# 1387          0          714      GasW        TA          N      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 88    6.920672         0           513   7.330405             0             0
# 140   6.761573         0             0   6.761573             0             0
# 144   7.454720         0             0   7.454720             1             0
# 221   6.917706      1257             0   7.726213             0             0
# 253   7.171657         0             0   7.171657             0             1
# 282   7.180831         0             0   7.180831             1             0
# 326   7.449498         0             0   7.449498             2             0
# 352   6.423247       495             0   7.013016             0             1
# 362   6.204558      1427             0   7.561122             0             0
# 431   6.992096       110             0   7.088409             0             0
# 435   6.717805       834             0   7.415175             1             0
# 439   6.527958       512             0   7.086738             0             0
# 488   7.476472       648             0   7.789040             0             0
# 591   7.454720       568             0   7.738924             1             0
# 636   6.684612         0             0   6.684612             0             0
# 762   6.638568       783             0   7.344073             0             0
# 811   6.742881         0             0   6.742881             1             0
# 885   7.443664         0             0   7.443664             1             0
# 942   7.272398         0             0   7.272398             2             0
# 969   6.998510         0             0   6.998510             1             0
# 985   7.059618         0             0   7.059618             1             0
# 1061  6.795706         0             0   6.795706             0             0
# 1075  6.866933       780             0   7.461640             0             0
# 1131  6.881411         0             0   6.881411             0             0
# 1158  7.365180         0             0   7.365180             0             0
# 1197  6.703188       875             0   7.432484             0             0
# 1200  6.761573         0             0   6.761573             0             0
# 1387  7.416980       862             0   7.834392             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 88           1         0             2             1          Fa
# 140          1         0             3             1          TA
# 144          2         0             6             2          TA
# 221          2         1             4             1          Gd
# 253          2         0             3             1          Gd
# 282          2         0             2             1          Gd
# 326          1         1             1             1          Gd
# 352          1         0             3             1          TA
# 362          3         0             4             1          Gd
# 431          1         0             4             1          TA
# 435          2         1             3             1          Gd
# 439          1         0             3             1          Gd
# 488          2         0             3             2          TA
# 591          2         1             3             1          Ex
# 636          1         0             1             1          Fa
# 762          2         1             3             1          Gd
# 811          1         0             1             1          Gd
# 885          2         0             2             1          Gd
# 942          2         0             4             2          TA
# 969          1         0             2             1          TA
# 985          1         0             3             1          TA
# 1061         1         0             2             1          TA
# 1075         1         1             3             1          TA
# 1131         1         0             3             1          TA
# 1158         2         0             3             1          Gd
# 1197         1         0             3             1          TA
# 1200         1         0             3             1          TA
# 1387         2         0             5             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 88               6        Typ           0     Missing    Missing         28.0
# 140              5        Typ           1          Po    Missing         28.0
# 144             10        Typ           0     Missing     Detchd         43.0
# 221              8        Typ           1          TA    BuiltIn          7.0
# 253              7       Min1           0     Missing     Attchd         43.0
# 282              6        Typ           1          Gd     Attchd          1.0
# 326              6        Typ           2          Gd     Attchd         15.0
# 352              5        Typ           0     Missing     Detchd         67.0
# 362              7        Typ           1          Ex    BuiltIn          6.0
# 431              7        Typ           0     Missing    Missing         28.0
# 435              6        Typ           1          TA     Attchd         13.0
# 439              7        Typ           0     Missing     Detchd          4.0
# 488             10        Mod           1          Gd     Attchd         36.0
# 591             10        Typ           1          Gd    BuiltIn          1.0
# 636              4   Rare_var           1          Po    Missing         28.0
# 762              7        Typ           0     Missing     Attchd          1.0
# 811              4        Typ           1          Gd     Attchd          4.0
# 885              5        Typ           1          TA     Attchd          9.0
# 942              8        Typ           0     Missing    Missing         28.0
# 969              6        Typ           0     Missing     Attchd         48.0
# 985              5        Typ           0     Missing     Detchd         58.0
# 1061             6        Typ           0     Missing     Detchd         14.0
# 1075             6        Typ           2          Gd     Attchd         67.0
# 1131             5        Typ           0     Missing    Missing         28.0
# 1158             7        Typ           0     Missing     Attchd          0.0
# 1197             7        Typ           1          Gd     Detchd         90.0
# 1200             5        Typ           0     Missing     Attchd         34.0
# 1387            10        Typ           1          Gd     Detchd         91.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 88        Missing           0           0    Missing    Missing          N
# 140       Missing           0           0    Missing    Missing          Y
# 144           Unf           2         504         TA         TA          Y
# 221           RFn           2         390         TA         TA          Y
# 253           RFn           1         309         TA         TA          Y
# 282           RFn           2         626         TA         TA          Y
# 326           Fin           2         473         TA         TA          Y
# 352           Unf           1         200         TA         Fa          Y
# 362           RFn           2         672         TA         TA          Y
# 431       Missing           0           0    Missing    Missing          N
# 435           RFn           2         550         TA         TA          Y
# 439           Unf           2         528         TA         TA          Y
# 488           Unf           2         520         TA         Fa          N
# 591           RFn           3         842         TA         TA          Y
# 636       Missing           0           0    Missing    Missing          N
# 762           Unf           2         614         TA         TA          Y
# 811           Fin           2         420         TA         TA          Y
# 885           Fin           2         506         TA         TA          Y
# 942       Missing           0           0    Missing    Missing          N
# 969           RFn           1         264         TA         TA          Y
# 985           Unf           1         240         TA         TA          Y
# 1061          RFn           3        1248         TA         TA          Y
# 1075          Unf           1         240         TA         TA          Y
# 1131      Missing           0           0    Missing    Missing          Y
# 1158          RFn           3         830         TA         TA          Y
# 1197          Unf           1         225         TA         TA          Y
# 1200          Unf           1         280         TA         TA          Y
# 1387          Unf           1         216         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 88             0            0            156          0            0
# 140            0            0              0          0            0
# 144            0            0              0          0            0
# 221          120           46              0          0            0
# 253          333            0              0          0            0
# 282          172           62              0          0            0
# 326          122           30              0          0            0
# 352           48            0              0          0            0
# 362            0            0            177          0            0
# 431            0           98              0          0            0
# 435          158           61              0          0            0
# 439            0           46              0          0            0
# 488          142            0              0          0            0
# 591          382          274              0          0            0
# 636            0            0              0          0            0
# 762          169           45              0          0            0
# 811          140            0              0          0            0
# 885           97           65              0          0            0
# 942          321            0              0          0            0
# 969            0            0              0          0            0
# 985            0           48              0          0            0
# 1061           0           20              0          0            0
# 1075           0            0              0          0            0
# 1131           0           28              0          0            0
# 1158           0           24              0          0            0
# 1197           0            0            330          0            0
# 1200           0            0              0          0            0
# 1387          88           15              0          0            0
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 88           0  Missing    MnPrv     Missing        0      10    2009
# 140          0  Missing  Missing     Missing        0       4    2010
# 144          0  Missing  Missing     Missing        0      11    2006
# 221          0  Missing  Missing     Missing        0      12    2009
# 253          0  Missing    MnPrv     Missing        0      10    2007
# 282          0  Missing  Missing     Missing        0       4    2009
# 326          0  Missing  Missing     Missing        0       5    2008
# 352          0  Missing  Missing     Missing        0       3    2008
# 362          0  Missing  Missing     Missing        0       7    2009
# 431          0  Missing    MnPrv     Missing        0       9    2008
# 435          0  Missing  Missing     Missing        0       4    2009
# 439          0  Missing    GdPrv        Shed      800       8    2009
# 488          0  Missing  Missing     Missing        0       5    2006
# 591          0  Missing  Missing     Missing        0       6    2009
# 636          0  Missing  Missing     Missing        0       1    2009
# 762          0  Missing  Missing     Missing        0       6    2010
# 811          0  Missing  Missing     Missing        0       6    2008
# 885          0  Missing  Missing     Missing        0       1    2008
# 942          0  Missing  Missing     Missing        0       8    2007
# 969          0  Missing  Missing     Missing        0       3    2006
# 985          0  Missing  Missing     Missing        0       8    2008
# 1061         0  Missing  Missing        Shed      560       8    2008
# 1075         0  Missing  Missing     Missing        0       7    2007
# 1131         0  Missing    MnPrv     Missing        0       9    2007
# 1158         0  Missing  Missing     Missing        0       6    2008
# 1197         0  Missing  Missing     Missing        0       7    2006
# 1200         0  Missing  Missing        Shed        0       7    2006
# 1387         0  Missing     GdWo     Missing        0       8    2007
#
#       SaleType SaleCondition  SalePrice
# 88    Rare_var       Abnorml  11.350407
# 140   Rare_var        Normal  11.652687
# 144   Rare_var       Abnorml  11.736069
# 221   Rare_var        Normal  12.206073
# 253   Rare_var        Normal  11.970350
# 282   Rare_var        Normal  12.242887
# 326   Rare_var        Normal  12.688499
# 352   Rare_var        Normal  11.461632
# 362   Rare_var        Normal  12.198544
# 431   Rare_var       Abnorml  11.288531
# 435   Rare_var        Normal  12.264342
# 439   Rare_var        Normal  11.608236
# 488   Rare_var        Normal  11.982929
# 591   Rare_var        Normal  13.021327
# 636   Rare_var        Normal  11.002100
# 762   Rare_var        Normal  12.279323
# 811   Rare_var        Normal  11.881035
# 885   Rare_var       Abnorml  12.703509
# 942   Rare_var       Abnorml  11.918391
# 969   Rare_var        Normal  11.849398
# 985   Rare_var        Normal  11.736069
# 1061  Rare_var        Normal  11.302204
# 1075  Rare_var        Normal  12.299108
# 1131  Rare_var       Abnorml  11.445717
# 1158  Rare_var       Partial  12.367885
# 1197  Rare_var        Normal  11.877569
# 1200  Rare_var       Abnorml  11.661776
# 1387  Rare_var        Family  11.820410

# %%
temp=data.MiscFeature.value_counts()/len(data)
temp_df=temp[temp>0.01].index
data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_var')

# %%
df_cpy=data
df_cpy
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley  \
# 0        1          60       RL     4.174387  9.041922   Pave  Missing
# 1        2          20       RL     4.382027  9.169518   Pave  Missing
# 2        3          60       RL     4.219508  9.328123   Pave  Missing
# 3        4          70       RL     4.094345  9.164296   Pave  Missing
# 4        5          60       RL     4.430817  9.565214   Pave  Missing
# ...    ...         ...      ...          ...       ...    ...      ...
# 1455  1456          60       RL     4.127134  8.976768   Pave  Missing
# 1456  1457          20       RL     4.442651  9.486076   Pave  Missing
# 1457  1458          70       RL     4.189655  9.109636   Pave  Missing
# 1458  1459          20       RL     4.219508  9.181632   Pave  Missing
# 1459  1460          20       RL     4.317488  9.204020   Pave  Missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0         Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1         Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2         IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3         IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4         IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# ...       ...         ...       ...       ...       ...          ...
# 1455      Reg         Lvl    AllPub    Inside       Gtl      Gilbert
# 1456      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1457      Reg         Lvl    AllPub    Inside       Gtl      Crawfor
# 1458      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1459      Reg         Lvl    AllPub    Inside       Gtl      Edwards
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0          Norm       Norm     1Fam     2Story            7            5
# 1         Feedr       Norm     1Fam     1Story            6            8
# 2          Norm       Norm     1Fam     2Story            7            5
# 3          Norm       Norm     1Fam     2Story            7            5
# 4          Norm       Norm     1Fam     2Story            8            5
# ...         ...        ...      ...        ...          ...          ...
# 1455       Norm       Norm     1Fam     2Story            6            5
# 1456       Norm       Norm     1Fam     1Story            6            6
# 1457       Norm       Norm     1Fam     2Story            7            9
# 1458       Norm       Norm     1Fam     1Story            5            6
# 1459       Norm       Norm     1Fam     1Story            5            6
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0             5             5     Gable  CompShg     VinylSd     VinylSd
# 1            31            31     Gable  CompShg     MetalSd     MetalSd
# 2             7             6     Gable  CompShg     VinylSd     VinylSd
# 3            91            36     Gable  CompShg     Wd Sdng     Wd Shng
# 4             8             8     Gable  CompShg     VinylSd     VinylSd
# ...         ...           ...       ...      ...         ...         ...
# 1455          8             7     Gable  CompShg     VinylSd     VinylSd
# 1456         32            22     Gable  CompShg     Plywood     Plywood
# 1457         69             4     Gable  CompShg     CemntBd     CmentBd
# 1458         60            14       Hip  CompShg     MetalSd     MetalSd
# 1459         43            43     Gable  CompShg     HdBoard     HdBoard
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0       BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 1          None         0.0        TA        TA     CBlock       Gd       TA
# 2       BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 3          None         0.0        TA        TA     BrkTil       TA       Gd
# 4       BrkFace       350.0        Gd        TA      PConc       Gd       TA
# ...         ...         ...       ...       ...        ...      ...      ...
# 1455       None         0.0        TA        TA      PConc       Gd       TA
# 1456      Stone       119.0        TA        TA     CBlock       Gd       TA
# 1457       None         0.0        Ex        Gd      Stone       TA       Gd
# 1458       None         0.0        TA        TA     CBlock       TA       TA
# 1459       None         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0     6.752270       854             0   7.444249             1             0
# 1     7.140453         0             0   7.140453             0             1
# 2     6.824374       866             0   7.487734             1             0
# 3     6.867974       756             0   7.448334             1             0
# 4     7.043160      1053             0   7.695303             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455  6.859615       694             0   7.406711             0             0
# 1456  7.636752         0             0   7.636752             1             0
# 1457  7.080026      1152             0   7.757906             0             0
# 1458  6.982863         0             0   6.982863             1             0
# 1459  7.135687         0             0   7.135687             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0     Missing     Attchd          5.0
# 1                6        Typ           1          TA     Attchd         31.0
# 2                6        Typ           1          TA     Attchd          7.0
# 3                7        Typ           1          Gd     Detchd          8.0
# 4                9        Typ           1          TA     Attchd          8.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd          8.0
# 1456             7       Min1           2          TA     Attchd         32.0
# 1457             9        Typ           2          Gd     Attchd         69.0
# 1458             5        Typ           0     Missing     Attchd         60.0
# 1459             6        Typ           0     Missing     Attchd         43.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0  Missing  Missing     Missing        0       2    2008
# 1            0  Missing  Missing     Missing        0       5    2007
# 2            0  Missing  Missing     Missing        0       9    2008
# 3            0  Missing  Missing     Missing        0       2    2006
# 4            0  Missing  Missing     Missing        0      12    2008
# ...        ...      ...      ...         ...      ...     ...     ...
# 1455         0  Missing  Missing     Missing        0       8    2007
# 1456         0  Missing    MnPrv     Missing        0       2    2010
# 1457         0  Missing    GdPrv        Shed     2500       5    2010
# 1458         0  Missing  Missing     Missing        0       4    2010
# 1459         0  Missing  Missing     Missing        0       6    2008
#
#      SaleType SaleCondition  SalePrice
# 0          WD        Normal  12.247694
# 1          WD        Normal  12.109011
# 2          WD        Normal  12.317167
# 3          WD       Abnorml  11.849398
# 4          WD        Normal  12.429216
# ...       ...           ...        ...
# 1455       WD        Normal  12.072541
# 1456       WD        Normal  12.254863
# 1457       WD        Normal  12.493130
# 1458       WD        Normal  11.864462
# 1459       WD        Normal  11.901583
#
# [1460 rows x 81 columns]

# %%
#another method of converting categorical 
#for feature in categorical_features:
    #labels_ordered=dataset.groupby([feature])['SalePrice'].mean().sort_values().index
    #labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    #dataset[feature]=dataset[feature].map(labels_ordered)

# %%
data=df_cpy.copy()
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5          5
# 1       Norm     1Fam     1Story            6            8         31
# 2       Norm     1Fam     2Story            7            5          7
# 3       Norm     1Fam     2Story            7            5         91
# 4       Norm     1Fam     2Story            8            5          8
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             5     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1            31     Gable  CompShg     MetalSd     MetalSd       None
# 2             6     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3            36     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             8     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr  6.752270       854             0
# 1    GasA        Ex          Y      SBrkr  7.140453         0             0
# 2    GasA        Ex          Y      SBrkr  6.824374       866             0
# 3    GasA        Gd          Y      SBrkr  6.867974       756             0
# 4    GasA        Ex          Y      SBrkr  7.043160      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0   7.444249             1             0         2         1             3
# 1   7.140453             0             1         2         0             3
# 2   7.487734             1             0         2         1             3
# 3   7.448334             1             0         1         0             3
# 4   7.695303             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0     Missing
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd          5.0          RFn           2         548         TA
# 1     Attchd         31.0          RFn           2         460         TA
# 2     Attchd          7.0          RFn           2         608         TA
# 3     Detchd          8.0          Unf           3         642         TA
# 4     Attchd          8.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# 0            0         0  Missing  Missing     Missing        0       2
# 1            0         0  Missing  Missing     Missing        0       5
# 2            0         0  Missing  Missing     Missing        0       9
# 3            0         0  Missing  Missing     Missing        0       2
# 4            0         0  Missing  Missing     Missing        0      12
#
#    YrSold SaleType SaleCondition  SalePrice
# 0    2008       WD        Normal  12.247694
# 1    2007       WD        Normal  12.109011
# 2    2008       WD        Normal  12.317167
# 3    2006       WD       Abnorml  11.849398
# 4    2008       WD        Normal  12.429216

# %%
data.groupby(data['Street'])['SalePrice'].mean()
# Out:
# Street
# Grvl    11.667435
# Pave    12.025522
# Name: SalePrice, dtype: float64

# %%
for feature in categorical_features:
    data.groupby(data[feature])['SalePrice'].mean().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
for feature in categorical_features:
    data[feature]=encoder.fit_transform(data[feature])

# %%
for feature in categorical_features:
    data.groupby(data[feature])['SalePrice'].mean().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %%
data.groupby(data['MSZoning'])['SalePrice'].mean()
# Out:
# MSZoning
# 0    11.118259
# 1    12.246616
# 2    11.749840
# 3    12.085885
# 4    11.692893
# Name: SalePrice, dtype: float64

# %% [markdown]
# Feature scaling

# %%
scaling_feature=[feature for feature in data.columns if feature not in ['Id','SalePrice'] ]
len(scaling_feature)
# Out:
# 79

# %%
feature_scale=[feature for feature in data.columns if feature not in ['Id','SalePrice']]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(data[feature_scale])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.transform(data[feature_scale])
# Out:
# array([[0.23529412, 0.5       , 0.41820812, ..., 0.5       , 1.        ,
#         0.5       ],
#        [0.        , 0.5       , 0.49506375, ..., 0.25      , 1.        ,
#         0.5       ],
#        [0.23529412, 0.5       , 0.434909  , ..., 0.5       , 1.        ,
#         0.5       ],
#        ...,
#        [0.29411765, 0.5       , 0.42385922, ..., 1.        , 1.        ,
#         0.5       ],
#        [0.        , 0.5       , 0.434909  , ..., 1.        , 1.        ,
#         0.5       ],
#        [0.        , 0.5       , 0.47117546, ..., 0.5       , 1.        ,
#         0.5       ]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([data[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(data[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
data['MSZoning'].unique()
# Out:
# array([0.5 , 0.75, 1.  , 0.  , 0.25])

# %%
data.to_csv('X_train.csv',index=False)
