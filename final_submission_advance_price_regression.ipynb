# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
df_train=pd.read_csv(r'C:\Users\kesha\data_set\advance_houseprice_prediction_train.csv')

# %% [markdown]
# # FEATURE ENGINEERING

# %%
df_cpy=df_train.copy()

# %%
df_cpy.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
##handling missing value in categorical feature
feature_cat_na=[feature for feature in df_cpy.columns if df_cpy[feature].isnull().sum()>0 and df_cpy[feature].dtypes=='O']
(feature_cat_na)
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
data=df_cpy.copy()
for feature in feature_cat_na:
    #data=df_cpy.copy()
    data[feature]=data[feature].fillna('Missing')

# %%
df_cpy[feature_cat_na]=data[feature_cat_na]

# %%
##handling missing value in numerical feature
feature_num_na=[feature for feature in df_cpy.columns if df_cpy[feature].isnull().sum()>0 and df_cpy[feature].dtypes!='O']

# %%
## We will print the numerical nan variables and percentage of missing values

for feature in feature_num_na:
    print("{}: {}% missing value".format(feature,np.around(df_cpy[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1774% missing value
# MasVnrArea: 0.0055% missing value
# GarageYrBlt: 0.0555% missing value

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    
       
    df_cpy[feature]=df_cpy['YrSold']-df_cpy[feature]

# %%
df_cpy[feature_num_na]=df_cpy[feature_num_na].fillna(df_cpy[feature_num_na].median())
#df_cpy['LotFrontage'].median()
df_cpy[feature_num_na].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
categorical_features=[feature for feature in df_cpy.columns if df_cpy[feature].dtype=='O']

# %%
data=df_cpy.copy()
for feature in categorical_features:
    temp=data[feature].value_counts()/len(data)
    temp_df=temp[temp>0.01].index
    data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_var')

# %%
df_cpy=data

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea','SalePrice']

for feature in num_features:
    df_cpy[feature]=np.log(df_cpy[feature])

# %%
df_cpy.shape
# Out:
# (1460, 81)

# %%
df_cpy1=df_cpy.copy()

# %%
df_cpy1.shape
# Out:
# (1460, 81)

# %%
pd.set_option("max_rows", None)

# %%
Q1 = df_cpy1['GrLivArea'].quantile(0.25)
Q3 = df_cpy1['GrLivArea'].quantile(0.75)
IQR = Q3 - Q1
print((Q1 - 1.5 * IQR))
print((Q1 + 1.5 * IQR))
df_cpy=df_cpy1[(df_cpy1['GrLivArea'] > (Q1 - 1.5 * IQR)) &(df_cpy1['GrLivArea'] < (Q3 + 1.5 * IQR))]
df_cpy.shape
# Out:
# 6.350013807614906
# 7.709046275973674
# (1450, 81)

# %%
df_cpy=df_cpy1

# %%
data_train=df_cpy
data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl     Rare_var      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data_train.drop('SalePrice',axis=1,inplace=True)
# Out:
# C:\Users\kesha\project\env\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl     Rare_var      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data_test=pd.read_csv(r'C:\Users\kesha\machine learning\advance_price_regression\data_test.csv')

# %%
data_test.shape
# Out:
# (1459, 80)

# %%
data_train.shape
# Out:
# (1450, 80)

# %%
data_com=pd.concat([data_train,data_test],axis=0)

# %%
data_com.shape
# Out:
# (2909, 80)

# %%
categorical_features=[feature for feature in data_com.columns if data_com[feature].dtype=='O']
#for feature in categorical_features:
    #print("{}: {}".format(feature,data_com[feature].nunique()))

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
for feature in categorical_features:
    data_com[feature]=encoder.fit_transform(data_com[feature])

# %%
data_train=data_com.iloc[0:1450,:]

# %%
data_train.shape
# Out:
# (1450, 80)

# %%
data_test=data_com.iloc[1450:,:]

# %%
data_test.shape
# Out:
# (1459, 80)

# %%
df_train.SalePrice
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
# 30       40000
# 31      149350
# 32      179900
# 33      165500
# 34      277500
# 35      309000
# 36      145000
# 37      153000
# 38      109000
# 39       82000
# 40      160000
# 41      170000
# 42      144000
# 43      130250
# 44      141000
# 45      319900
# 46      239686
# 47      249700
# 48      113000
# 49      127000
# 50      177000
# 51      114500
# 52      110000
# 53      385000
# 54      130000
# 55      180500
# 56      172500
# 57      196500
# ...

# %%
df_train.SalePrice.isnull().sum()
# Out:
# 0

# %%
data_train['SalePrice']=np.log(df_train['SalePrice'])
# Out:
# C:\Users\kesha\project\env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         3     4.174387  9.041922       0      1         3
# 1   2          20         3     4.382027  9.169518       0      1         3
# 2   3          60         3     4.219508  9.328123       0      1         0
# 3   4          70         3     4.094345  9.164296       0      1         0
# 4   5          60         3     4.430817  9.565214       0      1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          3          0             4           2
# 1            3          0          2          0            16           1
# 2            3          0          3          0             4           2
# 3            3          0          0          0             5           2
# 4            3          0          2          0            13           2
#
# ...

# %%
x_train=data_train.drop(['Id','SalePrice'],axis=1)

# %%
x_train.shape
# Out:
# (1450, 79)

# %%
y_train=data_train['SalePrice']

# %%
x_train.shape
# Out:
# (1450, 79)

# %% [markdown]
# # FEATURE SELECTION

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
feature_sel_model = SelectFromModel(Lasso(alpha=0.0008, random_state=0)) # remember to set the seed, the random state in this function
feature_sel_model.fit(x_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.0008, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
feature_sel_model.get_support()
# Out:
# array([False,  True, False,  True, False, False,  True,  True, False,
#         True, False,  True, False, False, False, False,  True,  True,
#         True,  True, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True, False,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#         True,  True, False,  True,  True,  True,  True])

# %%
selected_feat = x_train.columns[(feature_sel_model.get_support())]

# %%
len(selected_feat)
# Out:
# 61

# %%
x_train1=x_train[selected_feat]

# %%
x_train1.shape
# Out:
# (1450, 61)

# %%
#modal deployment
import xgboost
regressor=xgboost.XGBRegressor()

# %%
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

## Hyper Parameter Optimization
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
from sklearn.model_selection import RandomizedSearchCV
# Set up the random search with 4-fold cross validation
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=7, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(x_train1,y_train)
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=4)]: Done 350 out of 350 | elapsed:  2.6min finished
# RandomizedSearchCV(cv=7, error_score=nan,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=2,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=900, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
regressor=xgboost.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type='gain', interaction_constraints='',
             learning_rate=0.1, max_delta_step=0, max_depth=2,
             min_child_weight=1, missing=None, monotone_constraints='()',
             n_estimators=900, n_jobs=0, num_parallel_tree=1,
             objective='reg:squarederror', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
             validate_parameters=1, verbosity=None)

# %%
regressor.fit(x_train1,y_train)
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=2,
#              min_child_weight=1, missing=None, monotone_constraints='()',
#              n_estimators=900, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
x_test=data_test.drop(['Id'],axis=1)

# %%
x_test1=x_test[selected_feat]

# %%
x_test1.shape
# Out:
# (1459, 61)

# %%
y_pred=regressor.predict(x_test1)

# %%
y_pred
# Out:
# array([11.498362, 11.993389, 12.155098, ..., 11.966129, 11.631845,
#        12.314061], dtype=float32)

# %%
pred=pd.DataFrame(y_pred,columns=['SalePrice'])
np.exp(pred)
# Out:
#           SalePrice
# 0      98554.164062
# 1     161682.390625
# 2     190060.546875
# 3     194261.781250
# 4     188098.859375
# 5     170878.812500
# 6     172970.265625
# 7     165028.125000
# 8     180092.671875
# 9     126609.429688
# 10    175550.437500
# 11     93440.375000
# 12     97046.304688
# 13    149338.093750
# 14    123151.601562
# 15    368063.031250
# 16    245580.203125
# 17    289453.906250
# 18    252221.421875
# 19    494447.156250
# 20    320825.218750
# 21    206715.062500
# 22    173408.609375
# 23    168895.750000
# 24    178813.062500
# 25    198353.937500
# 26    349156.031250
# 27    225832.953125
# 28    201145.421875
# 29    227229.640625
# 30    194037.921875
# 31     71382.492188
# 32    193442.062500
# 33    296056.812500
# 34    287545.843750
# 35    243139.593750
# 36    187168.000000
# 37    165356.125000
# 38    160336.828125
# 39    151219.390625
# 40    182414.796875
# 41    146831.421875
# 42    305877.343750
# 43    239951.296875
# ...

# %%
df_final=pd.concat([data_test,np.exp(pred)],axis=1)
df_final.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0  1461          20         5     4.382027  9.360655       0      1         3
# 1  1462          20         3     4.394449  9.565704       0      1         0
# 2  1463          60         3     4.304065  9.534595       0      1         0
# 3  1464          60         3     4.356709  9.208138       0      1         0
# 4  1465         120         3     3.761200  8.518193       0      1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          3          0            11           1
# 1            3          0          0          0            11           2
# 2            3          0          3          0             7           2
# 3            3          0          3          0             7           2
# 4            1          0          3          0            21           2
#
# ...

# %%
datasets=df_final[['Id','SalePrice']]

# %%
datasets
# Out:
#         Id      SalePrice
# 0     1461   98554.164062
# 1     1462  161682.390625
# 2     1463  190060.546875
# 3     1464  194261.781250
# 4     1465  188098.859375
# 5     1466  170878.812500
# 6     1467  172970.265625
# 7     1468  165028.125000
# 8     1469  180092.671875
# 9     1470  126609.429688
# 10    1471  175550.437500
# 11    1472   93440.375000
# 12    1473   97046.304688
# 13    1474  149338.093750
# 14    1475  123151.601562
# 15    1476  368063.031250
# 16    1477  245580.203125
# 17    1478  289453.906250
# 18    1479  252221.421875
# 19    1480  494447.156250
# 20    1481  320825.218750
# 21    1482  206715.062500
# 22    1483  173408.609375
# 23    1484  168895.750000
# 24    1485  178813.062500
# 25    1486  198353.937500
# 26    1487  349156.031250
# 27    1488  225832.953125
# 28    1489  201145.421875
# 29    1490  227229.640625
# 30    1491  194037.921875
# 31    1492   71382.492188
# 32    1493  193442.062500
# 33    1494  296056.812500
# ...

# %%
datasets.to_csv('sample_submission.csv',index=False)
