# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
df_test=pd.read_csv(r'C:\Users\kesha\data_set\advance_houseprice_prediction_test.csv')

# %%
df_cpy=df_test.copy()

# %%
##handling missing value in categorical feature
feature_cat_na=[feature for feature in df_cpy.columns if df_cpy[feature].isnull().sum()>0 and df_cpy[feature].dtypes=='O']

# %%
data=df_cpy.copy()
for feature in feature_cat_na:
    #data=df_cpy.copy()
    data[feature]=data[feature].fillna('Missing')

# %%
df_cpy[feature_cat_na]=data[feature_cat_na]
df_cpy[feature_cat_na].head()
# Out:
#   MSZoning    Alley Utilities Exterior1st Exterior2nd MasVnrType BsmtQual  \
# 0       RH  Missing    AllPub     VinylSd     VinylSd       None       TA
# 1       RL  Missing    AllPub     Wd Sdng     Wd Sdng    BrkFace       TA
# 2       RL  Missing    AllPub     VinylSd     VinylSd       None       Gd
# 3       RL  Missing    AllPub     VinylSd     VinylSd    BrkFace       TA
# 4       RL  Missing    AllPub     HdBoard     HdBoard       None       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 KitchenQual Functional  \
# 0       TA           No          Rec          LwQ          TA        Typ
# 1       TA           No          ALQ          Unf          Gd        Typ
# 2       TA           No          GLQ          Unf          TA        Typ
# 3       TA           No          GLQ          Unf          Gd        Typ
# 4       TA           No          ALQ          Unf          Gd        Typ
#
#   FireplaceQu GarageType GarageFinish GarageQual GarageCond   PoolQC    Fence  \
# ...

# %%
##handling missing value in numerical feature
feature_num_na=[feature for feature in df_cpy.columns if df_cpy[feature].isnull().sum()>0 and df_cpy[feature].dtypes!='O']

# %%
## We will print the numerical nan variables and percentage of missing values

for feature in feature_num_na:
    print("{}: {}% missing value".format(feature,np.around(df_cpy[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1556% missing value
# MasVnrArea: 0.0103% missing value
# BsmtFinSF1: 0.0007% missing value
# BsmtFinSF2: 0.0007% missing value
# BsmtUnfSF: 0.0007% missing value
# TotalBsmtSF: 0.0007% missing value
# BsmtFullBath: 0.0014% missing value
# BsmtHalfBath: 0.0014% missing value
# GarageYrBlt: 0.0535% missing value
# GarageCars: 0.0007% missing value
# GarageArea: 0.0007% missing value

# %%
df_cpy[feature_num_na]=df_cpy[feature_num_na].fillna(df_cpy[feature_num_na].median())
#df_cpy['LotFrontage'].median()
df_cpy[feature_num_na].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# GarageYrBlt     0
# GarageCars      0
# GarageArea      0
# dtype: int64

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    df_cpy[feature]=df_cpy['YrSold']-df_cpy[feature]

# %%
df_cpy.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  Missing      Reg
# 1  1462          20       RL         81.0    14267   Pave  Missing      IR1
# 2  1463          60       RL         74.0    13830   Pave  Missing      IR1
# 3  1464          60       RL         78.0     9978   Pave  Missing      IR1
# 4  1465         120       RL         43.0     5005   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']

for feature in num_features:
    df_cpy[feature]=np.log(df_cpy[feature])

# %%
categorical_features=[feature for feature in df_cpy.columns if df_cpy[feature].dtype=='O']
for feature in categorical_features:
    print("{}: {}".format(feature,len(df_cpy[feature].unique())))
# Out:
# MSZoning: 6
# Street: 2
# Alley: 3
# LotShape: 4
# LandContour: 4
# Utilities: 2
# LotConfig: 5
# LandSlope: 3
# Neighborhood: 25
# Condition1: 9
# Condition2: 5
# BldgType: 5
# HouseStyle: 7
# RoofStyle: 6
# RoofMatl: 4
# Exterior1st: 14
# Exterior2nd: 16
# MasVnrType: 5
# ExterQual: 4
# ExterCond: 5
# Foundation: 6
# BsmtQual: 5
# BsmtCond: 5
# BsmtExposure: 5
# BsmtFinType1: 7
# BsmtFinType2: 7
# Heating: 4
# HeatingQC: 5
# CentralAir: 2
# Electrical: 4
# KitchenQual: 5
# Functional: 8
# FireplaceQu: 6
# GarageType: 7
# GarageFinish: 4
# GarageQual: 5
# GarageCond: 6
# PavedDrive: 3
# PoolQC: 3
# Fence: 5
# MiscFeature: 4
# SaleType: 10
# SaleCondition: 6

# %%
data=df_cpy.copy()
for feature in categorical_features:
    temp=data[feature].value_counts()/len(data)
    temp_df=temp[temp>0.01].index
    data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_var')

# %%
df_cpy=data
df_cpy.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0  1461          20  Rare_var     4.382027  9.360655   Pave  Missing      Reg
# 1  1462          20        RL     4.394449  9.565704   Pave  Missing      IR1
# 2  1463          60        RL     4.304065  9.534595   Pave  Missing      IR1
# 3  1464          60        RL     4.356709  9.208138   Pave  Missing      IR1
# 4  1465         120        RL     3.761200  8.518193   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_cpy.shape
# Out:
# (1459, 80)

# %%
data_test=df_cpy.to_csv('data_test.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-53-e66c30220d02> in <module>
# ----> 1 data_test=df_cpy.to_csv('data_test.csv')
#
# ~\project\env\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\project\env\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-17e0581fc746> in <module>
# ----> 1 data_test.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
